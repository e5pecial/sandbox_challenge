# %%
import pandas as pd
import numpy as np

from scipy import sparse
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import LabelEncoder

import lightgbm as lgbm

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import joblib

# %% [markdown]
# ### Здесь используем датасет с численными фичами

# %%
X_train = sparse.load_npz('concat_features_train.npz')
y_train = pd.read_csv('../sparse/train_labels.csv', names=['label'])

X_test = sparse.load_npz('concat_features_test.npz')

# %% [markdown]
# Обучим на 10 стратифицированных фолдах LGBMClassifier, на лидерборд зашлем усредненное предсказание по десяти фолдам, а также оценим OOF-предсказания

# %%
try:
    folds_idx = joblib.load('10folds.pkl')
except:
    folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    folds_idx = [
        (train_idx, val_idx) 
        for train_idx, val_idx in folds.split(X_train, y=y_train['label'])
    ]

    joblib.dump(folds_idx, '10folds.pkl')

# %%
params = {'subsample_freq': 2,
          'subsample_for_bin': 100, 
          'subsample': 0.7, 
          'scale_pos_weight': 1, 
          'reg_lambda': 0.2, 
          'reg_alpha': 7, 
          'objective': 'binary', 
          'num_leaves': 50, 
          'min_split_gain': 2.0, 
          'n_estimators': 300,
          'min_child_weight': 3,
          'min_child_samples': 100, 
          'metric': 'auc', 
          'max_depth': 20, 
          'max_bin': 100, 
          'learning_rate': 0.075, 
          'random_state': 44,
          'colsample_bytree': 0.7}

# %%
num_boost_round=150
early_stopping_rounds=120

# %%
test_preds = []
oof_preds = np.zeros(X_train.shape[0])
final_preds = np.zeros(X_test.shape[0])
auc_scores = []
    
for n_fold, (train_idx, valid_idx) in enumerate(folds_idx):
    train_x, train_y = X_train.tocsr()[train_idx], y_train['label'].iloc[train_idx]
    valid_x, valid_y = X_train.tocsr()[valid_idx], y_train['label'].iloc[valid_idx]
    

    
    d_train = lgbm.Dataset(train_x, label=train_y)
    d_valid = lgbm.Dataset(valid_x, label=valid_y)
    clf = lgbm.train(params, 
                         d_train, 
                         valid_sets=[d_train, d_valid], 
                         valid_names=['train','valid'], 
                         num_boost_round=num_boost_round,
                         early_stopping_rounds=early_stopping_rounds,
                         verbose_eval=10,
                      )
    
    oof_preds[valid_idx] = clf.predict(valid_x, num_iteration=clf.best_iteration)
    y_pred = clf.predict(X_test, num_iteration=clf.best_iteration)
    test_preds.append(y_pred)
    auc_scores.append(roc_auc_score(valid_y, oof_preds[valid_idx]))
    
    print('Fold %2d AUC : %.6f' % (n_fold + 1, auc_scores[-1]))
    
print("\n", f"Mean AUC:{np.mean(auc_scores)}", 
      f"std: {np.std(auc_scores)}",
      f"oof roc-auc:{roc_auc_score(y_train['label'], oof_preds)}")
# Out:
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.666943	valid's auc: 0.649582
# [20]	train's auc: 0.686407	valid's auc: 0.661549
# [30]	train's auc: 0.700047	valid's auc: 0.670057
# [40]	train's auc: 0.709968	valid's auc: 0.674843
# [50]	train's auc: 0.717732	valid's auc: 0.677267
# [60]	train's auc: 0.725048	valid's auc: 0.679026
# [70]	train's auc: 0.731635	valid's auc: 0.679821
# [80]	train's auc: 0.737534	valid's auc: 0.681846
# [90]	train's auc: 0.742981	valid's auc: 0.681744
# [100]	train's auc: 0.748309	valid's auc: 0.68184
# [110]	train's auc: 0.753222	valid's auc: 0.681761
# [120]	train's auc: 0.757892	valid's auc: 0.682486
# [130]	train's auc: 0.762159	valid's auc: 0.682458
# [140]	train's auc: 0.7669	valid's auc: 0.682419
# [150]	train's auc: 0.77087	valid's auc: 0.682013
# [160]	train's auc: 0.77471	valid's auc: 0.681376
# [170]	train's auc: 0.778033	valid's auc: 0.681426
# [180]	train's auc: 0.781499	valid's auc: 0.680746
# [190]	train's auc: 0.785092	valid's auc: 0.68138
# [200]	train's auc: 0.788247	valid's auc: 0.680725
# [210]	train's auc: 0.791179	valid's auc: 0.680383
# [220]	train's auc: 0.793952	valid's auc: 0.680262
# [230]	train's auc: 0.796558	valid's auc: 0.680001
# [240]	train's auc: 0.799295	valid's auc: 0.679749
# Early stopping, best iteration is:
# [123]	train's auc: 0.759243	valid's auc: 0.682856
# Fold  1 AUC : 0.682856
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.670665	valid's auc: 0.64735
# [20]	train's auc: 0.686122	valid's auc: 0.655659
# [30]	train's auc: 0.698711	valid's auc: 0.662672
# [40]	train's auc: 0.707805	valid's auc: 0.666203
# [50]	train's auc: 0.715753	valid's auc: 0.669797
# [60]	train's auc: 0.722616	valid's auc: 0.672393
# [70]	train's auc: 0.72928	valid's auc: 0.674565
# [80]	train's auc: 0.735315	valid's auc: 0.675876
# [90]	train's auc: 0.740657	valid's auc: 0.678016
# [100]	train's auc: 0.745568	valid's auc: 0.678739
# [110]	train's auc: 0.75059	valid's auc: 0.679808
# [120]	train's auc: 0.75524	valid's auc: 0.680409
# [130]	train's auc: 0.759632	valid's auc: 0.681026
# [140]	train's auc: 0.763892	valid's auc: 0.680486
# [150]	train's auc: 0.76777	valid's auc: 0.681
# [160]	train's auc: 0.771458	valid's auc: 0.681156
# [170]	train's auc: 0.775041	valid's auc: 0.68116
# [180]	train's auc: 0.77854	valid's auc: 0.681053
# [190]	train's auc: 0.781702	valid's auc: 0.681344
# [200]	train's auc: 0.784706	valid's auc: 0.681343
# [210]	train's auc: 0.787649	valid's auc: 0.681513
# [220]	train's auc: 0.790383	valid's auc: 0.681392
# [230]	train's auc: 0.793292	valid's auc: 0.680984
# [240]	train's auc: 0.795897	valid's auc: 0.680987
# [250]	train's auc: 0.798306	valid's auc: 0.681132
# [260]	train's auc: 0.800728	valid's auc: 0.681369
# [270]	train's auc: 0.802903	valid's auc: 0.68127
# [280]	train's auc: 0.805275	valid's auc: 0.680737
# [290]	train's auc: 0.807215	valid's auc: 0.680676
# [300]	train's auc: 0.809512	valid's auc: 0.680401
# Did not meet early stopping. Best iteration is:
# [300]	train's auc: 0.809512	valid's auc: 0.680401
# Fold  2 AUC : 0.680401
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.668197	valid's auc: 0.653527
# [20]	train's auc: 0.686878	valid's auc: 0.665385
# [30]	train's auc: 0.698623	valid's auc: 0.672091
# [40]	train's auc: 0.708235	valid's auc: 0.676186
# [50]	train's auc: 0.716513	valid's auc: 0.681335
# [60]	train's auc: 0.723811	valid's auc: 0.683115
# [70]	train's auc: 0.730062	valid's auc: 0.684736
# [80]	train's auc: 0.735527	valid's auc: 0.685865
# [90]	train's auc: 0.74105	valid's auc: 0.686016
# [100]	train's auc: 0.746346	valid's auc: 0.686634
# [110]	train's auc: 0.751063	valid's auc: 0.686855
# [120]	train's auc: 0.75601	valid's auc: 0.68708
# [130]	train's auc: 0.760458	valid's auc: 0.687588
# [140]	train's auc: 0.764462	valid's auc: 0.688151
# [150]	train's auc: 0.768594	valid's auc: 0.687862
# [160]	train's auc: 0.772169	valid's auc: 0.687552
# [170]	train's auc: 0.775981	valid's auc: 0.688036
# [180]	train's auc: 0.779276	valid's auc: 0.687611
# [190]	train's auc: 0.782508	valid's auc: 0.687638
# [200]	train's auc: 0.785566	valid's auc: 0.688026
# [210]	train's auc: 0.78869	valid's auc: 0.688181
# [220]	train's auc: 0.791602	valid's auc: 0.688408
# [230]	train's auc: 0.794164	valid's auc: 0.688482
# [240]	train's auc: 0.796666	valid's auc: 0.68813
# [250]	train's auc: 0.799065	valid's auc: 0.688075
# [260]	train's auc: 0.801386	valid's auc: 0.687871
# [270]	train's auc: 0.803564	valid's auc: 0.687803
# [280]	train's auc: 0.805865	valid's auc: 0.688031
# [290]	train's auc: 0.808109	valid's auc: 0.6883
# [300]	train's auc: 0.810077	valid's auc: 0.688458
# Did not meet early stopping. Best iteration is:
# [300]	train's auc: 0.810077	valid's auc: 0.688458
# Fold  3 AUC : 0.688458
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.673774	valid's auc: 0.646763
# [20]	train's auc: 0.689691	valid's auc: 0.655966
# [30]	train's auc: 0.700678	valid's auc: 0.661439
# [40]	train's auc: 0.710957	valid's auc: 0.665701
# [50]	train's auc: 0.718627	valid's auc: 0.667447
# [60]	train's auc: 0.725709	valid's auc: 0.668985
# [70]	train's auc: 0.732162	valid's auc: 0.67014
# [80]	train's auc: 0.738193	valid's auc: 0.67207
# [90]	train's auc: 0.743515	valid's auc: 0.671976
# [100]	train's auc: 0.748725	valid's auc: 0.672339
# [110]	train's auc: 0.753673	valid's auc: 0.672776
# [120]	train's auc: 0.757965	valid's auc: 0.673617
# [130]	train's auc: 0.762169	valid's auc: 0.673887
# [140]	train's auc: 0.766074	valid's auc: 0.67446
# [150]	train's auc: 0.770159	valid's auc: 0.674982
# [160]	train's auc: 0.774045	valid's auc: 0.675239
# [170]	train's auc: 0.777704	valid's auc: 0.674495
# [180]	train's auc: 0.781191	valid's auc: 0.67465
# [190]	train's auc: 0.78444	valid's auc: 0.674288
# [200]	train's auc: 0.787621	valid's auc: 0.674225
# [210]	train's auc: 0.790523	valid's auc: 0.674065
# [220]	train's auc: 0.793463	valid's auc: 0.674042
# [230]	train's auc: 0.796116	valid's auc: 0.673889
# [240]	train's auc: 0.798705	valid's auc: 0.673465
# [250]	train's auc: 0.801105	valid's auc: 0.673785
# [260]	train's auc: 0.80353	valid's auc: 0.674153
# [270]	train's auc: 0.806105	valid's auc: 0.673842
# Early stopping, best iteration is:
# [158]	train's auc: 0.773297	valid's auc: 0.675338
# Fold  4 AUC : 0.675338
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.670208	valid's auc: 0.643301
# [20]	train's auc: 0.687485	valid's auc: 0.657094
# [30]	train's auc: 0.700293	valid's auc: 0.664635
# [40]	train's auc: 0.709618	valid's auc: 0.668485
# [50]	train's auc: 0.717763	valid's auc: 0.670816
# [60]	train's auc: 0.724574	valid's auc: 0.673913
# [70]	train's auc: 0.731019	valid's auc: 0.675642
# [80]	train's auc: 0.736832	valid's auc: 0.677179
# [90]	train's auc: 0.742452	valid's auc: 0.678393
# [100]	train's auc: 0.747567	valid's auc: 0.679105
# [110]	train's auc: 0.752704	valid's auc: 0.679622
# [120]	train's auc: 0.757341	valid's auc: 0.67928
# [130]	train's auc: 0.761865	valid's auc: 0.678904
# [140]	train's auc: 0.766056	valid's auc: 0.678077
# [150]	train's auc: 0.769616	valid's auc: 0.678792
# [160]	train's auc: 0.773317	valid's auc: 0.678458
# [170]	train's auc: 0.777052	valid's auc: 0.678667
# [180]	train's auc: 0.780495	valid's auc: 0.67886
# [190]	train's auc: 0.783707	valid's auc: 0.67844
# [200]	train's auc: 0.78652	valid's auc: 0.677733
# [210]	train's auc: 0.789314	valid's auc: 0.677791
# [220]	train's auc: 0.792255	valid's auc: 0.677484
# [230]	train's auc: 0.794937	valid's auc: 0.677358
# Early stopping, best iteration is:
# [111]	train's auc: 0.753185	valid's auc: 0.679718
# Fold  5 AUC : 0.679718
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.667811	valid's auc: 0.657215
# [20]	train's auc: 0.688167	valid's auc: 0.668906
# [30]	train's auc: 0.70004	valid's auc: 0.675302
# [40]	train's auc: 0.709004	valid's auc: 0.678186
# [50]	train's auc: 0.717223	valid's auc: 0.681758
# [60]	train's auc: 0.724075	valid's auc: 0.683548
# [70]	train's auc: 0.730339	valid's auc: 0.685329
# [80]	train's auc: 0.736414	valid's auc: 0.685827
# [90]	train's auc: 0.741915	valid's auc: 0.68709
# [100]	train's auc: 0.747469	valid's auc: 0.687443
# [110]	train's auc: 0.752368	valid's auc: 0.687405
# [120]	train's auc: 0.757064	valid's auc: 0.688323
# [130]	train's auc: 0.761485	valid's auc: 0.688917
# [140]	train's auc: 0.76548	valid's auc: 0.689492
# [150]	train's auc: 0.769462	valid's auc: 0.6897
# [160]	train's auc: 0.773477	valid's auc: 0.689972
# [170]	train's auc: 0.77728	valid's auc: 0.689888
# [180]	train's auc: 0.780597	valid's auc: 0.6897
# [190]	train's auc: 0.784094	valid's auc: 0.689747
# [200]	train's auc: 0.787427	valid's auc: 0.689741
# [210]	train's auc: 0.790495	valid's auc: 0.689745
# [220]	train's auc: 0.793315	valid's auc: 0.690006
# [230]	train's auc: 0.79599	valid's auc: 0.690358
# [240]	train's auc: 0.798713	valid's auc: 0.690072
# [250]	train's auc: 0.801143	valid's auc: 0.689969
# [260]	train's auc: 0.803553	valid's auc: 0.689375
# [270]	train's auc: 0.805998	valid's auc: 0.689269
# [280]	train's auc: 0.808176	valid's auc: 0.688843
# [290]	train's auc: 0.810135	valid's auc: 0.68876
# [300]	train's auc: 0.81232	valid's auc: 0.68874
# Did not meet early stopping. Best iteration is:
# [300]	train's auc: 0.81232	valid's auc: 0.68874
# Fold  6 AUC : 0.688740
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.66688	valid's auc: 0.638326
# [20]	train's auc: 0.686628	valid's auc: 0.653198
# [30]	train's auc: 0.699778	valid's auc: 0.658747
# [40]	train's auc: 0.709035	valid's auc: 0.664126
# [50]	train's auc: 0.717352	valid's auc: 0.66718
# [60]	train's auc: 0.724368	valid's auc: 0.669285
# [70]	train's auc: 0.730858	valid's auc: 0.670992
# [80]	train's auc: 0.736548	valid's auc: 0.673071
# [90]	train's auc: 0.742061	valid's auc: 0.674282
# [100]	train's auc: 0.74684	valid's auc: 0.67557
# [110]	train's auc: 0.751709	valid's auc: 0.676133
# [120]	train's auc: 0.756229	valid's auc: 0.67696
# [130]	train's auc: 0.760672	valid's auc: 0.677252
# [140]	train's auc: 0.764979	valid's auc: 0.677449
# [150]	train's auc: 0.769026	valid's auc: 0.67738
# [160]	train's auc: 0.772628	valid's auc: 0.677497
# [170]	train's auc: 0.7761	valid's auc: 0.677935
# [180]	train's auc: 0.779542	valid's auc: 0.677937
# [190]	train's auc: 0.783068	valid's auc: 0.678462
# [200]	train's auc: 0.786383	valid's auc: 0.678811
# [210]	train's auc: 0.789488	valid's auc: 0.679154
# [220]	train's auc: 0.792352	valid's auc: 0.679148
# [230]	train's auc: 0.794911	valid's auc: 0.678917
# [240]	train's auc: 0.797366	valid's auc: 0.679289
# [250]	train's auc: 0.799798	valid's auc: 0.678849
# [260]	train's auc: 0.802511	valid's auc: 0.678937
# [270]	train's auc: 0.804861	valid's auc: 0.67958
# [280]	train's auc: 0.80742	valid's auc: 0.679378
# [290]	train's auc: 0.809754	valid's auc: 0.6788
# [300]	train's auc: 0.811566	valid's auc: 0.679011
# Did not meet early stopping. Best iteration is:
# [300]	train's auc: 0.811566	valid's auc: 0.679011
# Fold  7 AUC : 0.679011
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.670671	valid's auc: 0.654902
# [20]	train's auc: 0.688864	valid's auc: 0.667258
# [30]	train's auc: 0.701684	valid's auc: 0.674084
# [40]	train's auc: 0.710982	valid's auc: 0.677874
# [50]	train's auc: 0.719102	valid's auc: 0.680735
# [60]	train's auc: 0.725657	valid's auc: 0.682607
# [70]	train's auc: 0.731963	valid's auc: 0.68398
# [80]	train's auc: 0.73798	valid's auc: 0.684587
# [90]	train's auc: 0.743199	valid's auc: 0.684873
# [100]	train's auc: 0.748495	valid's auc: 0.685291
# [110]	train's auc: 0.753683	valid's auc: 0.685743
# [120]	train's auc: 0.758722	valid's auc: 0.685144
# [130]	train's auc: 0.762843	valid's auc: 0.685374
# [140]	train's auc: 0.766802	valid's auc: 0.685391
# [150]	train's auc: 0.770907	valid's auc: 0.685807
# [160]	train's auc: 0.774788	valid's auc: 0.685785
# [170]	train's auc: 0.778458	valid's auc: 0.685548
# [180]	train's auc: 0.781817	valid's auc: 0.685646
# [190]	train's auc: 0.785404	valid's auc: 0.685534
# [200]	train's auc: 0.78828	valid's auc: 0.685499
# [210]	train's auc: 0.791194	valid's auc: 0.684985
# [220]	train's auc: 0.793923	valid's auc: 0.684969
# [230]	train's auc: 0.796414	valid's auc: 0.685099
# [240]	train's auc: 0.799125	valid's auc: 0.68518
# [250]	train's auc: 0.801671	valid's auc: 0.685727
# [260]	train's auc: 0.803851	valid's auc: 0.685473
# [270]	train's auc: 0.806292	valid's auc: 0.685165
# Early stopping, best iteration is:
# [153]	train's auc: 0.772132	valid's auc: 0.686027
# Fold  8 AUC : 0.686027
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.669483	valid's auc: 0.644722
# [20]	train's auc: 0.688816	valid's auc: 0.659175
# [30]	train's auc: 0.700891	valid's auc: 0.665603
# [40]	train's auc: 0.709642	valid's auc: 0.669283
# [50]	train's auc: 0.717601	valid's auc: 0.672693
# [60]	train's auc: 0.724835	valid's auc: 0.674382
# [70]	train's auc: 0.731025	valid's auc: 0.675909
# [80]	train's auc: 0.736882	valid's auc: 0.677178
# [90]	train's auc: 0.742644	valid's auc: 0.67785
# [100]	train's auc: 0.747865	valid's auc: 0.677912
# [110]	train's auc: 0.752745	valid's auc: 0.67867
# [120]	train's auc: 0.757221	valid's auc: 0.679315
# [130]	train's auc: 0.761588	valid's auc: 0.679485
# [140]	train's auc: 0.765692	valid's auc: 0.679588
# [150]	train's auc: 0.769672	valid's auc: 0.679437
# [160]	train's auc: 0.773499	valid's auc: 0.679717
# [170]	train's auc: 0.777107	valid's auc: 0.6801
# [180]	train's auc: 0.780335	valid's auc: 0.680274
# [190]	train's auc: 0.783566	valid's auc: 0.680679
# [200]	train's auc: 0.786554	valid's auc: 0.680484
# [210]	train's auc: 0.789427	valid's auc: 0.680248
# [220]	train's auc: 0.792408	valid's auc: 0.680272
# [230]	train's auc: 0.795276	valid's auc: 0.68026
# [240]	train's auc: 0.797625	valid's auc: 0.67976
# [250]	train's auc: 0.80022	valid's auc: 0.679776
# [260]	train's auc: 0.802853	valid's auc: 0.679409
# [270]	train's auc: 0.805053	valid's auc: 0.679179
# [280]	train's auc: 0.807293	valid's auc: 0.679305
# [290]	train's auc: 0.809349	valid's auc: 0.679655
# [300]	train's auc: 0.811265	valid's auc: 0.679461
# Did not meet early stopping. Best iteration is:
# [300]	train's auc: 0.811265	valid's auc: 0.679461
# Fold  9 AUC : 0.679461
# Training until validation scores don't improve for 120 rounds.
# [10]	train's auc: 0.671528	valid's auc: 0.647616
# [20]	train's auc: 0.686402	valid's auc: 0.656792
# [30]	train's auc: 0.698558	valid's auc: 0.665195
# [40]	train's auc: 0.708484	valid's auc: 0.668283
# [50]	train's auc: 0.716144	valid's auc: 0.671419
# [60]	train's auc: 0.722804	valid's auc: 0.674387
# [70]	train's auc: 0.728879	valid's auc: 0.676965
# [80]	train's auc: 0.734691	valid's auc: 0.678734
# [90]	train's auc: 0.740094	valid's auc: 0.680538
# [100]	train's auc: 0.744989	valid's auc: 0.681002
# [110]	train's auc: 0.749771	valid's auc: 0.682944
# [120]	train's auc: 0.754438	valid's auc: 0.683198
# [130]	train's auc: 0.75844	valid's auc: 0.6837
# [140]	train's auc: 0.762639	valid's auc: 0.683653
# [150]	train's auc: 0.766557	valid's auc: 0.683976
# [160]	train's auc: 0.770285	valid's auc: 0.684397
# [170]	train's auc: 0.773501	valid's auc: 0.684928
# [180]	train's auc: 0.777128	valid's auc: 0.683893
# [190]	train's auc: 0.780564	valid's auc: 0.683298
# [200]	train's auc: 0.783365	valid's auc: 0.683293
# [210]	train's auc: 0.786075	valid's auc: 0.683427
# [220]	train's auc: 0.789043	valid's auc: 0.683471
# [230]	train's auc: 0.791701	valid's auc: 0.683668
# [240]	train's auc: 0.794284	valid's auc: 0.68397
# [250]	train's auc: 0.796588	valid's auc: 0.684441
# [260]	train's auc: 0.798873	valid's auc: 0.684266
# [270]	train's auc: 0.801104	valid's auc: 0.683854
# [280]	train's auc: 0.803054	valid's auc: 0.683642
# [290]	train's auc: 0.804772	valid's auc: 0.683756
# Early stopping, best iteration is:
# [171]	train's auc: 0.773921	valid's auc: 0.684973
# Fold 10 AUC : 0.684973
#
#  Mean AUC:0.682498265966945 std: 0.00421876929498404 oof roc-auc:0.6823876227541152

# %%
oof_roc_auc = roc_auc_score(y_train['label'], oof_preds)

# %%
final_preds = list(map(lambda x: np.mean(x), zip(*test_preds)))

# %%
cuids_test = pd.read_csv('../mlboot_dataset/mlboot_test.tsv.gz', delimiter='\t', compression='gzip', index_col='cuid')

# %%
sub = pd.read_csv('../sparse/test_cuid.csv', names=['cuid'], index_col='cuid')

# %%
sub['pred'] = final_preds
sub = sub.reindex(cuids_test.index)

# %%
sub['pred'].to_csv(f'../output/lgbm_oof_predict_{oof_roc_auc}.csv', index=False)

# %% [markdown]
# ### На лидерборде получили:
# ```
# П: 0.7449432
# Ф: 0.7429291
# ```

# %% [markdown]
# ## Сблендим с логрегрессией с коэффициентами:

# %%
logreg = pd.read_csv('../output/baseline_c002_sag.csv', names=['label'])

# %%
lgbm = pd.read_csv('../output/lgbm_oof_predict_0.6823876227541152.csv', names=['label'])

# %%
pred = lgbm['label'] * 0.9 + logreg['label'] * 0.1

# %%
pred.to_csv('../output/0.9lgbm10folds_0.6823876+0.1logreg.csv', index=False)

# %% [markdown]
# ## На лидерборде:
#
# ```
# П: 0.7453606
# 4 / 15
# Ф: 0.7449608
# 4 / 15
# ```

# %% [markdown]
# ![yeah](meme.png)

# %% [markdown]
# # Итого:
# ## За три вечера получен вполне годный и стойки к переобучению на лидерборде результат, который еще можно улучшать
